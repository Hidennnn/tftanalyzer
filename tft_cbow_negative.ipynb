# %%
from tensorflow.python.keras.layers import Embedding, Dot, Input, Flatten
from tensorflow.python.keras.models import Model
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.python.keras.callbacks import ModelCheckpoint
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.io as pio

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
def strip_lines(line):
    line = line.replace(')', '')
    line = line.replace('(', '')
    line = line.replace('\"', '')
    line = line.replace('\n', '')
    line = line.replace(',', '')
    line = line.replace('\'', '')
    line = line.split()
    return line

# %%
sentences = []
with open('pary.txt', 'r') as file:
    lines = file.readlines()
    for line in lines:
        sentences.append(strip_lines(line))

# %%
words = set(word for sentence in sentences for word in sentence)
word2idx = {word: i + 1 for i, word in enumerate(words)}
idx2word = {i: word for word, i in word2idx.items()}

# %%
def generate_training_data(sentences, word2idx, window_size, num_negative_samples):
    X, Y, vec = [], [], []
    for sentence in sentences:
        sentence = [word2idx[word] for word in sentence]
        for i, target_word in enumerate(sentence):
            for j in range(max(0, i - window_size), min(len(sentence), i + window_size + 1)):
                if i != j:
                    X.append(target_word)
                    Y.append(sentence[j])
                    vec.append(1)
                    negative_samples = np.random.choice(list(word2idx.values()), size=num_negative_samples)
                    for neg_word in negative_samples:
                        X.append(target_word)
                        Y.append(neg_word)
                        vec.append(0)
    return np.array(X), np.array(Y), vec

# %%
X, Y, vec = generate_training_data(sentences, word2idx, window_size=3, num_negative_samples=1)
V = len(words)

# %%
X_train, X_rest, Y_train, Y_rest, vec_train, vec_rest = train_test_split(X, Y, vec, test_size=0.3, random_state=42)
X_test, X_val, Y_test, Y_val, vec_test, vec_val = train_test_split(X_rest, Y_rest, vec_rest, test_size=0.3, random_state=42)

input_target = Input((1,))
input_context = Input((1,))

embedding = Embedding(V, 50, input_length=1, name='embedding')
target_embedding = embedding(input_target)
context_embedding = embedding(input_context)

dot_product = Dot(axes=-1)([target_embedding, context_embedding])
output = Flatten()(dot_product)

model = Model(inputs=[input_target, input_context], outputs=output)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

checkpoint = ModelCheckpoint(filepath='checkpointy_tft_negative.h5',
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True
                             )

# %%
model.fit([X_train, Y_train], np.array(vec_train),
          validation_data=([X_val, Y_val], np.array(vec_val)),
         epochs=50, batch_size=4096, callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 1432/1432 [==============================] - 5s 3ms/step - loss: 0.5454 - accuracy: 0.7638 - val_loss: 0.5477 - val_accuracy: 0.7623
#
# Epoch 00001: val_accuracy improved from 0.76139 to 0.76231, saving model to checkpointy_tft_negative.h5
# Epoch 2/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5455 - accuracy: 0.7638 - val_loss: 0.5482 - val_accuracy: 0.7636
#
# Epoch 00002: val_accuracy improved from 0.76231 to 0.76360, saving model to checkpointy_tft_negative.h5
# Epoch 3/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5442 - accuracy: 0.7642 - val_loss: 0.5476 - val_accuracy: 0.7625
#
# Epoch 00003: val_accuracy did not improve from 0.76360
# Epoch 4/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5427 - accuracy: 0.7651 - val_loss: 0.5455 - val_accuracy: 0.7645
#
# Epoch 00004: val_accuracy improved from 0.76360 to 0.76454, saving model to checkpointy_tft_negative.h5
# Epoch 5/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5416 - accuracy: 0.7667 - val_loss: 0.5455 - val_accuracy: 0.7662
#
# Epoch 00005: val_accuracy improved from 0.76454 to 0.76617, saving model to checkpointy_tft_negative.h5
# Epoch 6/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5406 - accuracy: 0.7673 - val_loss: 0.5457 - val_accuracy: 0.7648
#
# Epoch 00006: val_accuracy did not improve from 0.76617
# Epoch 7/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5377 - accuracy: 0.7685 - val_loss: 0.5378 - val_accuracy: 0.7679
#
# Epoch 00007: val_accuracy improved from 0.76617 to 0.76786, saving model to checkpointy_tft_negative.h5
# Epoch 8/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5365 - accuracy: 0.7694 - val_loss: 0.5483 - val_accuracy: 0.7685
#
# Epoch 00008: val_accuracy improved from 0.76786 to 0.76846, saving model to checkpointy_tft_negative.h5
# Epoch 9/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5393 - accuracy: 0.7699 - val_loss: 0.5425 - val_accuracy: 0.7690
#
# Epoch 00009: val_accuracy improved from 0.76846 to 0.76898, saving model to checkpointy_tft_negative.h5
# Epoch 10/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5393 - accuracy: 0.7705 - val_loss: 0.5450 - val_accuracy: 0.7690
#
# Epoch 00010: val_accuracy improved from 0.76898 to 0.76904, saving model to checkpointy_tft_negative.h5
# Epoch 11/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5400 - accuracy: 0.7719 - val_loss: 0.5469 - val_accuracy: 0.7704
#
# Epoch 00011: val_accuracy improved from 0.76904 to 0.77035, saving model to checkpointy_tft_negative.h5
# Epoch 12/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5416 - accuracy: 0.7723 - val_loss: 0.5461 - val_accuracy: 0.7718
#
# Epoch 00012: val_accuracy improved from 0.77035 to 0.77180, saving model to checkpointy_tft_negative.h5
# Epoch 13/50
# 1432/1432 [==============================] - 5s 3ms/step - loss: 0.5419 - accuracy: 0.7740 - val_loss: 0.5473 - val_accuracy: 0.7735
#
# Epoch 00013: val_accuracy improved from 0.77180 to 0.77355, saving model to checkpointy_tft_negative.h5
# Epoch 14/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5420 - accuracy: 0.7758 - val_loss: 0.5520 - val_accuracy: 0.7746
#
# Epoch 00014: val_accuracy improved from 0.77355 to 0.77457, saving model to checkpointy_tft_negative.h5
# Epoch 15/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5461 - accuracy: 0.7768 - val_loss: 0.5514 - val_accuracy: 0.7760
#
# Epoch 00015: val_accuracy improved from 0.77457 to 0.77600, saving model to checkpointy_tft_negative.h5
# Epoch 16/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5459 - accuracy: 0.7776 - val_loss: 0.5504 - val_accuracy: 0.7776
#
# Epoch 00016: val_accuracy improved from 0.77600 to 0.77755, saving model to checkpointy_tft_negative.h5
# Epoch 17/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5468 - accuracy: 0.7797 - val_loss: 0.5565 - val_accuracy: 0.7799
#
# Epoch 00017: val_accuracy improved from 0.77755 to 0.77987, saving model to checkpointy_tft_negative.h5
# Epoch 18/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5540 - accuracy: 0.7797 - val_loss: 0.5632 - val_accuracy: 0.7784
#
# Epoch 00018: val_accuracy did not improve from 0.77987
# Epoch 19/50
# 1432/1432 [==============================] - 5s 3ms/step - loss: 0.5549 - accuracy: 0.7805 - val_loss: 0.5637 - val_accuracy: 0.7782
#
# Epoch 00019: val_accuracy did not improve from 0.77987
# Epoch 20/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5563 - accuracy: 0.7805 - val_loss: 0.5608 - val_accuracy: 0.7820
#
# Epoch 00020: val_accuracy improved from 0.77987 to 0.78196, saving model to checkpointy_tft_negative.h5
# Epoch 21/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5584 - accuracy: 0.7836 - val_loss: 0.5739 - val_accuracy: 0.7808
#
# Epoch 00021: val_accuracy did not improve from 0.78196
# Epoch 22/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5643 - accuracy: 0.7835 - val_loss: 0.5662 - val_accuracy: 0.7841
#
# Epoch 00022: val_accuracy improved from 0.78196 to 0.78411, saving model to checkpointy_tft_negative.h5
# Epoch 23/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5640 - accuracy: 0.7850 - val_loss: 0.5733 - val_accuracy: 0.7847
#
# Epoch 00023: val_accuracy improved from 0.78411 to 0.78473, saving model to checkpointy_tft_negative.h5
# Epoch 24/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5659 - accuracy: 0.7860 - val_loss: 0.5724 - val_accuracy: 0.7842
#
# Epoch 00024: val_accuracy did not improve from 0.78473
# Epoch 25/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5697 - accuracy: 0.7855 - val_loss: 0.5786 - val_accuracy: 0.7838
#
# Epoch 00025: val_accuracy did not improve from 0.78473
# Epoch 26/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5697 - accuracy: 0.7879 - val_loss: 0.5775 - val_accuracy: 0.7874
#
# Epoch 00026: val_accuracy improved from 0.78473 to 0.78736, saving model to checkpointy_tft_negative.h5
# Epoch 27/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5747 - accuracy: 0.7892 - val_loss: 0.5852 - val_accuracy: 0.7879
#
# Epoch 00027: val_accuracy improved from 0.78736 to 0.78789, saving model to checkpointy_tft_negative.h5
# Epoch 28/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5790 - accuracy: 0.7904 - val_loss: 0.5933 - val_accuracy: 0.7893
#
# Epoch 00028: val_accuracy improved from 0.78789 to 0.78932, saving model to checkpointy_tft_negative.h5
# Epoch 29/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5940 - accuracy: 0.7909 - val_loss: 0.6024 - val_accuracy: 0.7902
#
# Epoch 00029: val_accuracy improved from 0.78932 to 0.79019, saving model to checkpointy_tft_negative.h5
# Epoch 30/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.5998 - accuracy: 0.7909 - val_loss: 0.6062 - val_accuracy: 0.7907
#
# Epoch 00030: val_accuracy improved from 0.79019 to 0.79071, saving model to checkpointy_tft_negative.h5
# Epoch 31/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.6038 - accuracy: 0.7912 - val_loss: 0.6156 - val_accuracy: 0.7905
#
# Epoch 00031: val_accuracy did not improve from 0.79071
# Epoch 32/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.6081 - accuracy: 0.7920 - val_loss: 0.6072 - val_accuracy: 0.7922
#
# Epoch 00032: val_accuracy improved from 0.79071 to 0.79220, saving model to checkpointy_tft_negative.h5
# Epoch 33/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.6048 - accuracy: 0.7934 - val_loss: 0.6146 - val_accuracy: 0.7929
#
# Epoch 00033: val_accuracy improved from 0.79220 to 0.79291, saving model to checkpointy_tft_negative.h5
# Epoch 34/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.6126 - accuracy: 0.7943 - val_loss: 0.6274 - val_accuracy: 0.7925
#
# Epoch 00034: val_accuracy did not improve from 0.79291
# Epoch 35/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.6228 - accuracy: 0.7939 - val_loss: 0.6242 - val_accuracy: 0.7925
#
# Epoch 00035: val_accuracy did not improve from 0.79291
# Epoch 36/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.6313 - accuracy: 0.7947 - val_loss: 0.6495 - val_accuracy: 0.7929
#
# Epoch 00036: val_accuracy improved from 0.79291 to 0.79294, saving model to checkpointy_tft_negative.h5
# Epoch 37/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.6491 - accuracy: 0.7932 - val_loss: 0.6584 - val_accuracy: 0.7916
#
# Epoch 00037: val_accuracy did not improve from 0.79294
# Epoch 38/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.6597 - accuracy: 0.7945 - val_loss: 0.6706 - val_accuracy: 0.7947
#
# Epoch 00038: val_accuracy improved from 0.79294 to 0.79474, saving model to checkpointy_tft_negative.h5
# Epoch 39/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.6655 - accuracy: 0.7952 - val_loss: 0.6741 - val_accuracy: 0.7943
#
# Epoch 00039: val_accuracy did not improve from 0.79474
# Epoch 40/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.6681 - accuracy: 0.7955 - val_loss: 0.6805 - val_accuracy: 0.7943
#
# Epoch 00040: val_accuracy did not improve from 0.79474
# Epoch 41/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.7037 - accuracy: 0.7941 - val_loss: 0.7211 - val_accuracy: 0.7917
#
# Epoch 00041: val_accuracy did not improve from 0.79474
# Epoch 42/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.7107 - accuracy: 0.7945 - val_loss: 0.7285 - val_accuracy: 0.7943
#
# Epoch 00042: val_accuracy did not improve from 0.79474
# Epoch 43/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.7238 - accuracy: 0.7947 - val_loss: 0.7328 - val_accuracy: 0.7922
#
# Epoch 00043: val_accuracy did not improve from 0.79474
# Epoch 44/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.7259 - accuracy: 0.7957 - val_loss: 0.7464 - val_accuracy: 0.7950
#
# Epoch 00044: val_accuracy improved from 0.79474 to 0.79495, saving model to checkpointy_tft_negative.h5
# Epoch 45/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.7495 - accuracy: 0.7953 - val_loss: 0.7607 - val_accuracy: 0.7947
#
# Epoch 00045: val_accuracy did not improve from 0.79495
# Epoch 46/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.7555 - accuracy: 0.7951 - val_loss: 0.7776 - val_accuracy: 0.7932
#
# Epoch 00046: val_accuracy did not improve from 0.79495
# Epoch 47/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.7771 - accuracy: 0.7948 - val_loss: 0.7988 - val_accuracy: 0.7948
#
# Epoch 00047: val_accuracy did not improve from 0.79495
# Epoch 48/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.7985 - accuracy: 0.7939 - val_loss: 0.8184 - val_accuracy: 0.7905
#
# Epoch 00048: val_accuracy did not improve from 0.79495
# Epoch 49/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.8132 - accuracy: 0.7927 - val_loss: 0.8229 - val_accuracy: 0.7924
#
# Epoch 00049: val_accuracy did not improve from 0.79495
# Epoch 50/50
# 1432/1432 [==============================] - 4s 3ms/step - loss: 0.8231 - accuracy: 0.7935 - val_loss: 0.8374 - val_accuracy: 0.7926
#
# Epoch 00050: val_accuracy did not improve from 0.79495

# %%
loss, accuracy = model.evaluate([X_test, Y_test], np.array(vec_test))
# Out:
# 54974/54974 [==============================] - 71s 1ms/step - loss: 0.8372 - accuracy: 0.7934

# %%
pio.renderers.default = 'iframe'

# %%
weights = embedding.get_weights()[0]
labels = np.arange(1, 449)

pca = PCA(n_components = 1)
data = pca.fit_transform(weights)
data = np.array(data[:, 0])

trace = go.Scatter(
    x=labels,
    y=data,
    mode='markers',
    marker=dict(
        color='rgba(0, 0, 200, .8)',
        size=10
    ),
    hoverinfo='text',
    text=[f'Word: {w}<br>Embedding: {e}'
          for w, e in zip(idx2word.values(), data)]
)

layout = go.Layout(
    title='PCA',
    xaxis=dict(title='Word'),
    yaxis=dict(title='Embedding'),
    hovermode='x',
)

fig = go.Figure(data=[trace], layout=layout)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_147.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
