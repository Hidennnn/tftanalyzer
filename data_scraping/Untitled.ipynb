# %%
import pandas as pd
import os 
import numpy as np
import math

# %%
df = pd.read_csv(f'04.04.2024/BR1_2914370380.csv')

# %%
if math.isnan():
    print(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 if math.isnan(df.iloc[3]['item_1']):
#       2     print(1)
#
# TypeError: must be real number, not str

# %%
isinstance(df.iloc[3]['item_1'], float)
# Out:
# False

# %%
max_t = len(os.listdir('04.04.2024'))
count_t = 0
sum_champs = 0
for file in os.listdir('04.04.2024'):
    df = pd.read_csv(f'04.04.2024/{file}')
    for x in range(df.shape[0]):
        if isinstance(df.iloc[x]['item_1'], float):
            sum_champs += 1
        if isinstance(df.iloc[x]['item_2'], float):
            sum_champs += 1
        if isinstance(df.iloc[x]['item_3'], float):
            sum_champs += 1
    count_t += 1
    print(f'{count_t}/{max_t}')
# Out:
# 1/8416
# 2/8416
# 3/8416
# 4/8416
# 5/8416
# 6/8416
# 7/8416
# 8/8416
# 9/8416
# 10/8416
# 11/8416
# 12/8416
# 13/8416
# 14/8416
# 15/8416
# 16/8416
# 17/8416
# 18/8416
# 19/8416
# 20/8416
# 21/8416
# 22/8416
# 23/8416
# 24/8416
# 25/8416
# 26/8416
# 27/8416
# 28/8416
# 29/8416
# 30/8416
# 31/8416
# 32/8416
# 33/8416
# 34/8416
# 35/8416
# 36/8416
# 37/8416
# 38/8416
# 39/8416
# 40/8416
# 41/8416
# 42/8416
# 43/8416
# 44/8416
# 45/8416
# 46/8416
# 47/8416
# 48/8416
# 49/8416
# 50/8416
# 51/8416
# 52/8416
# 53/8416
# 54/8416
# 55/8416
# 56/8416
# 57/8416
# 58/8416
# 59/8416
# 60/8416
# 61/8416
# 62/8416
# 63/8416
# 64/8416
# 65/8416
# 66/8416
# 67/8416
# 68/8416
# 69/8416
# 70/8416
# 71/8416
# 72/8416
# 73/8416
# 74/8416
# 75/8416
# 76/8416
# 77/8416
# 78/8416
# 79/8416
# 80/8416
# 81/8416
# 82/8416
# 83/8416
# 84/8416
# 85/8416
# 86/8416
# 87/8416
# 88/8416
# 89/8416
# 90/8416
# 91/8416
# 92/8416
# 93/8416
# 94/8416
# 95/8416
# 96/8416
# 97/8416
# 98/8416
# 99/8416
# 100/8416
# ...

# %%
print(len(set(players)))
# Out:
# 7097

# %%
sum_champs
# Out:
# 910669

# %%
if pd.NA:
    print(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 if pd.NA:
#       2     print(1)
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\missing.pyx:446, in pandas._libs.missing.NAType.__bool__()
#
# TypeError: boolean value of NA is ambiguous
